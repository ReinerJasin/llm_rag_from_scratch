# %% [markdown]
# # RAG from Scratch: Query Construction

# %% [markdown]
# The query construction step is the phase where you transform the user’s raw question into a better search query that the retriever can understand.
