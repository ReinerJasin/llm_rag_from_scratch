# %% [markdown]
# # RAG from Scratch: Query Construction

# %% [markdown]
# The query construction step is the phase where you transform the user’s raw question (natural language) into a specific query syntax that the retriever can understand for the particular data type (because the data might be stored in different formats).
